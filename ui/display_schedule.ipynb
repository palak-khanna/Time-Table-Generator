# %%
def display_schedule(best_schedule):
    # Code to display the timetable, might be as simple as a print statement or updating the UI widget
    # Assuming it's a dictionary or a formatted string:
    timetable_str = f"Generated Timetable:\n{best_schedule}"  # Replace with actual timetable formatting
    print(timetable_str)  # or you could update the UI text area here directly
